# %% [markdown]
# # Analysieren der Daten in csv Datei um Ähnlichkeitsmaße zu entwickeln und zu implementieren

# %%
import pandas as pd

# CSV-Datei einlesen
df = pd.read_csv('Wohnungskartei_1.csv', sep=';')

# %%
# Für jede Spalte die verschiedenen Ausprägungen ausgeben
for column in df.columns:
    print(f"Spalte '{column}' hat {len(df[column].unique())} Asprägungen: ")
    print(f"{df[column].unique()} \n\n")
# Out:
# Spalte 'Zimmerzahl' hat 10 Asprägungen:
# ['Zwei Zimmer' '4 Zimmer' 'Ein Zimmer' '6 Zimmer' '2-3 Zimmer' '5 Zimmer'
#  '3-4 Zimmer' '4-5 Zimmer' '5-6 Zimmer' '3 Zimmer']
#
#
# Spalte 'Stockwerk' hat 11 Asprägungen:
# ['1.Stock' '3.Stock' 'EG' '2.Stock' '5.Stock' '4.Stock' '8.Stock'
#  '9.Stock' '6.Stock' '7.Stock' '10.Stock']
#
#
# Spalte 'Heizung' hat 6 Asprägungen:
# ['Gas-Zentral' 'Gas-Etage' 'Öl' 'Pellets' 'Erdwärme' 'Lüftungsheizung']
#
#
# Spalte 'Hausmeister' hat 2 Asprägungen:
# ['nein' 'ja']
#
#
# Spalte 'Kindergarten' hat 3 Asprägungen:
# ['nah' 'fern' 'erreichbar']
#
#
# Spalte 'Schule' hat 3 Asprägungen:
# ['erreichbar' 'nah' 'fern']
#
#
# Spalte 'S-Bahn' hat 4 Asprägungen:
# ['nah' 'erreichbar' 'nein' 'mit Bus']
#
#
# Spalte 'Garage' hat 2 Asprägungen:
# ['nein' 'ja']
#
#
# Spalte 'Miete' hat 13 Asprägungen:
# ['251-300' '551-600' '751-800' '401-450' '201-250' '651-700' '501-550'
#  '601-650' '801-850' '701-750' '451-500' '901-950' '851-900']
#
#
# Spalte 'Nebenkosten' hat 7 Asprägungen:
# ['50-100' '201-250' '151-200' 'unter 50' '251-300' '101-150' 'über 300']
#
#
# Spalte 'Alter' hat 11 Asprägungen:
# ['16-20 Jahre' '4-7 Jahre' '7-10 Jahre' '11-15 Jahre' '31-50 Jahre'
#  'ueber 100' 'Neubau' '51-75 Jahre' '1-3 Jahre' '76-100 Jahre'
#  '21-30 Jahre']
#
#
# Spalte 'Aufzug' hat 2 Asprägungen:
# ['ja' 'nein']
#
#
# Spalte 'Lage' hat 5 Asprägungen:
# ['Hauptstrasse' 'Wohngebiet' 'Abgelegen' 'Spielstrasse' 'Nebenstrasse']
#
#
# Spalte 'Entfernung' hat 7 Asprägungen:
# ['< 1 km' '5-10 km' '21-30 km' '< 3 km' '3-5 km' '> 30 km' '11-20 km']
#
#
# Spalte 'Kaution' hat 3 Asprägungen:
# ['keine' 'ueber 3000' '1000-1500']
#
#
# Spalte 'Kueche' hat 3 Asprägungen:
# ['Küche (alt)' 'Küche (neu)' 'keine']
#
#
# Spalte 'Bad' hat 5 Asprägungen:
# ['Dusche' 'Badewanne' 'Dusche + Wanne' 'Dusche auf Flur' 'Waschbecken']
#
#
# Spalte 'Balkon' hat 2 Asprägungen:
# ['nein' 'ja']
#
#
# Spalte 'Terrasse' hat 2 Asprägungen:
# ['nein' 'ja']
#
#
# Spalte 'Kehrwoche' hat 2 Asprägungen:
# ['nein' 'ja']
#
#
# Spalte 'Moebliert' hat 3 Asprägungen:
# ['nein' 'ja' 'teilmoebliert']
#
#
# Spalte 'Quadratmeter' hat 11 Asprägungen:
# ['31-40' '91-100' '81-90' '20-30' 'über 120' '51-60' '101-110' '71-80'
#  '111-120' '61-70' '41-50']
#
#
# Spalte 'Kabelanschluss' hat 2 Asprägungen:
# ['nein' 'ja']
#
#
# Spalte 'Deckenhöhe' hat 4 Asprägungen:
# [250 260 280 300]
#
#
# Spalte 'Abstellraum' hat 2 Asprägungen:
# ['ja' 'nein']
#
#
# Spalte 'Waschraum' hat 2 Asprägungen:
# ['nein' 'ja']
#
#
# Spalte 'Klasse' hat 5 Asprägungen:
# ['Studierende' 'DINK' 'Kleinfamilie' 'Single' 'Expatriate']

# %%
# Dicts zum Mappen der Ausprägungen auf numerische Werte

# Spalte 'Zimmerzahl'
zimmerzahl_dict = {'Zwei Zimmer': 2, '4 Zimmer': 4, 'Ein Zimmer': 1, '6 Zimmer': 6, '2-3 Zimmer': 2.5, '5 Zimmer': 5,
 '3-4 Zimmer': 3.5, '4-5 Zimmer': 4.5, '5-6 Zimmer': 5.5, '3 Zimmer': 3}

stockwerk_dict = {'1.Stock': 1, '3.Stock': 3, 'EG': 0, '2.Stock': 2, '5.Stock': 5, '4.Stock': 4, '8.Stock': 8, '9.Stock': 9,
 '6.Stock': 6, '7.Stock': 7, '10.Stock': 10}

# heizung_dict_Nominal = {'Gas-Zentral': 1, 'Gas-Etage': 2, 'Öl': 3, 'Pellets': 4, 'Erdwärme': 5, 'Lüftungsheizung': 6} # TODO: ! Macht keine Sinn hier eine Ordnung zu definieren

# hausmeister_dict = {'nein': 0, 'ja': 1}

kindergarten_dict = {'nah': 1, 'erreichbar': 2, 'fern': 3}
# Distanzen wobei 'nah' die geringste Distanz, 'erreichbar' eine mittlere und 'fern' die größte Distanz bezeichnet.

schule_dict = {'nah': 1, 'erreichbar': 2, 'fern': 3}

sbahn_dict = {'nah': 1, 'erreichbar': 2, 'mit Bus': 3, 'nein': 4}

# garage_dict = {'nein': 0, 'ja': 1}

miete_dict = {'251-300': 275, '551-600': 575, '751-800': 775, '401-450': 425, '201-250': 225, '651-700': 675, '501-550': 525,
 '601-650': 625, '801-850': 825, '701-750': 725, '451-500': 475, '901-950': 925, '851-900': 875}

nebenkosten_dict = {'50-100': 75, '201-250': 225, '151-200': 175, 'unter 50': 25, '251-300': 275, '101-150': 125, 'über 300': 325}


alter_dict = {'16-20 Jahre': 18, '4-7 Jahre': 5.5, '7-10 Jahre': 8.5, '11-15 Jahre': 13, '31-50 Jahre': 40.5, 'ueber 100': 100,
 'Neubau': 0, '51-75 Jahre': 63, '1-3 Jahre': 2, '76-100 Jahre': 88, '21-30 Jahre': 25.5}

# aufzug_dict = {'ja': 1, 'nein': 0}

#TODO: ! Macht keine Sinn hier eine Ordnung zu definieren
# lage_dict_Nominal = {'Hauptstrasse': 1, 'Wohngebiet': 2, 'Abgelegen': 3, 'Spielstrasse': 4, 'Nebenstrasse': 5}

entfernung_dict = {'< 1 km': 0.5, '5-10 km': 7.5, '21-30 km': 25.5, '< 3 km': 1.5, '3-5 km': 4, '> 30 km': 35.5, '11-20 km': 15.5}

kaution_dict = {'keine': 0, 'ueber 3000': 3500, '1000-1500': 1250}

# kueche_dict_Nominal = {'Küche (alt)': 1, 'Küche (neu)': 2, 'keine': 0}


# bad_dict_Nominal = {'Dusche': 1, 'Badewanne': 2, 'Dusche + Wanne': 3, 'Dusche auf Flur': 4, 'Waschbecken': 5}

# balkon_dict = {'nein': 0, 'ja': 1}
# 
# terrasse_dict = {'nein': 0, 'ja': 1}
# 
# kehrwoche_dict = {'nein': 0, 'ja': 1}
# 
moebilisiert_dict = {'nein': 0, 'teilmoebliert': 1, 'ja': 2}

quadratmeter_dict = {'31-40': 35.5, '91-100': 95.5, '81-90': 85.5, '20-30': 25.5, 'über 120': 125, '51-60': 55.5, '101-110': 105.5,
 '71-80': 75.5, '111-120': 115.5, '61-70': 65.5, '41-50': 45.5}

# kabelanschluss_dict = {'nein': 0, 'ja': 1}

# deckenhoehe_dict = {'250': 250, '260': 260, '280':280, '300':300}

# abstellraum_dict = {'ja': 1, 'nein': 0}

# waschraum_dict = {'nein': 0, 'ja': 1}

# klasse_dict = {'Studierende': 0, 'DINK':1, 'Kleinfamilie':2, 'Single':3, 'Expatriate':4}

# %% [markdown]
# ## Entwicklung eines Ähnlichkeitmaßes für die versch. Ausprägungen

# %%
def similiarity_simple(x, y) -> float:
    diff = abs(x - y)
    # Berechnung der Ähnlichkeit als inverse Funktion der Differenz
    similarity = 1 / (1 + diff)
    
    return similarity

def similiarity_yes_no(x, y) -> bool:
    if x == y:
        return True
    return False

def similiarity_relative_to_interval(dict_values: dict, x, y) -> float:
    diff = abs(x -y)
    max_distance = max(dict_values.values()) - min(dict_values.values())
    relative_distance = diff / max_distance
    return relative_distance

# %% [markdown]
# ## Klassifikationslogik
#
# 1. Berechnung der Ähnlichkeiten: Berechnen der Ähnlichkeit zu jedem Fall in der Fallbasis.
# 2. Auswahl ähnlichster Fälle: Auswahl des oder der ähnlichsten Fälle:
#     - Auswahl des einzigen ähnlichsten Falls.
#     - Auswahl der Top-N ähnlichsten Fälle.
#     - Auswahl aller Fälle, die eine bestimmte Ähnlichkeitsschwelle überschreiten.

# %%
count = df['Klasse'].value_counts()
print(count)
# Out:
# Klasse
# Kleinfamilie    128
# Studierende      83
# DINK             40
# Expatriate       10
# Single            4
# Name: count, dtype: int64

# %% [markdown]
# Da die Klassen im Datensatz nicht gleichmäßig aufgeteilt sind macht es keinen Sinn mehrere ähnliche Fälle auszuwählen.
# Beispiel: Wähle Top 5 Ähnlichste Fälle. Zwar ist Single der ähnlichste Fall aber Kleinfamilie ist sehr häufig und könnte somit die anderen 4 Plätze besetzen. Es macht deshalb aber keinen Sinn von Kleinfamilie auszugehen.
#
# --> Wähle nur den Ähnlichsten Fall aus!

# %%
# First row of df
print(dict(df.iloc[0]))
# Out:
# {'Zimmerzahl': 'Zwei Zimmer', 'Stockwerk': '1.Stock', 'Heizung': 'Gas-Zentral', 'Hausmeister': 'nein', 'Kindergarten': 'nah', 'Schule': 'erreichbar', 'S-Bahn': 'nah', 'Garage': 'nein', 'Miete': '251-300', 'Nebenkosten': '50-100', 'Alter': '16-20 Jahre', 'Aufzug': 'ja', 'Lage': 'Hauptstrasse', 'Entfernung': '< 1 km', 'Kaution': 'keine', 'Kueche': 'Küche (alt)', 'Bad': 'Dusche', 'Balkon': 'nein', 'Terrasse': 'nein', 'Kehrwoche': 'nein', 'Moebliert': 'nein', 'Quadratmeter': '31-40', 'Kabelanschluss': 'nein', 'Deckenhöhe': 250, 'Abstellraum': 'ja', 'Waschraum': 'nein', 'Klasse': 'Studierende'}

# %%
def get_similiarity_to_every_case(wohnung:dict, df:pd.DataFrame) -> pd.DataFrame:
    # Berechnung der Ähnlichkeiten für jeden Fall in der Fallbasis
    df['Similarity'] = 0
    # keine Ähnlichkeit für die Ausprägung berechnen wenn wohnung nicht diese Ausprägung hat
    for i in range(len(df)):
        similarity = 0
        for key, value in wohnung.items():
            if df.iloc[i][key]:
                if key == 'Zimmerzahl':
                    similarity += similiarity_relative_to_interval(zimmerzahl_dict, zimmerzahl_dict[value], zimmerzahl_dict[df.iloc[i][key]])
                elif key == 'Stockwerk':
                    similarity += similiarity_relative_to_interval(stockwerk_dict, stockwerk_dict[value], stockwerk_dict[df.iloc[i][key]])
                elif key == 'Heizung':
                    similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Hausmeister':
                    similarity += similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Kindergarten':
                    similarity += similiarity_relative_to_interval(kindergarten_dict, kindergarten_dict[value], kindergarten_dict[df.iloc[i][key]])
                elif key == 'Schule':
                    similarity += similiarity_relative_to_interval(schule_dict, schule_dict[value], schule_dict[df.iloc[i][key]])
                elif key == 'S-Bahn':
                    similarity += similiarity_relative_to_interval(sbahn_dict, sbahn_dict[value], sbahn_dict[df.iloc[i][key]])
                elif key == 'Garage':
                    similarity += similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Miete':
                    similarity += similiarity_simple(miete_dict[value], miete_dict[df.iloc[i][key]])
                elif key == 'Nebenkosten':
                    similarity += similiarity_simple(nebenkosten_dict[value], nebenkosten_dict[df.iloc[i][key]])
                elif key == 'Alter':
                    similarity += similiarity_simple(alter_dict[value], alter_dict[df.iloc[i][key]])
                elif key == 'Entfernung':
                    similarity += similiarity_simple(entfernung_dict[value], entfernung_dict[df.iloc[i][key]])
                elif key == 'Kaution':
                    similarity += similiarity_relative_to_interval(kaution_dict ,kaution_dict[value], kaution_dict[df.iloc[i][key]])
                elif key == 'Deckenhöhe':
                    # print(value)
                    similarity += similiarity_simple(value, df.iloc[i][key])
                elif key == 'Moebliert':
                    similarity += similiarity_relative_to_interval(moebilisiert_dict, moebilisiert_dict[value], moebilisiert_dict[df.iloc[i][key]])
                elif key == 'Quadratmeter':
                    similarity += similiarity_simple(quadratmeter_dict[value], quadratmeter_dict[df.iloc[i][key]])
                elif key == 'Kueche':
                    similarity += similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Waschraum':
                    similarity += similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Balkon':
                    similarity += similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Abstellraum':
                    similarity += similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Aufzug':
                    similarity += similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Lage':
                    similarity += similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Kabelanschluss':
                    similarity += similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Terrasse':
                    similarity += similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Kehrwoche':
                    similarity += similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Bad':
                    similarity += similiarity_yes_no(value, df.iloc[i][key])
                elif key == 'Klasse':
                    print('Warning! Klasse angegeben!')
                else:
                    print(f"Key '{key}' not found!")
        df.at[i, 'Similarity'] = similarity
    return df

# %%
# Get similiarities and find most similiar case

df_with_similarities = get_similiarity_to_every_case(dict(df.iloc[0]), df)

display(df_with_similarities)

# get similiarty of most similiar case and the class of the most similiar case
most_similiar_case = df_with_similarities[df_with_similarities['Similarity'] == df_with_similarities['Similarity'].max()]

print(f"Most similiar case: \n{most_similiar_case}")
# Out:
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# C:\Users\bensc\AppData\Local\Temp\ipykernel_13796\675423988.py:66: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '13.325412292389528' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.at[i, 'Similarity'] = similarity
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
# 250
# Warning! Klasse angegeben!
#       Zimmerzahl Stockwerk      Heizung Hausmeister Kindergarten      Schule  \
# 0    Zwei Zimmer   1.Stock  Gas-Zentral        nein          nah  erreichbar
# 1       4 Zimmer   3.Stock    Gas-Etage          ja         fern         nah
# 2       4 Zimmer        EG    Gas-Etage        nein   erreichbar         nah
# 3     Ein Zimmer   2.Stock           Öl        nein   erreichbar        fern
# 4       6 Zimmer   3.Stock    Gas-Etage          ja   erreichbar         nah
# ..           ...       ...          ...         ...          ...         ...
# 260   Ein Zimmer   5.Stock     Erdwärme        nein          nah        fern
# 261     5 Zimmer        EG      Pellets        nein   erreichbar         nah
# 262   3-4 Zimmer   6.Stock           Öl          ja          nah        fern
# 263   4-5 Zimmer   3.Stock    Gas-Etage        nein   erreichbar         nah
# 264   3-4 Zimmer   2.Stock     Erdwärme        nein   erreichbar         nah
#
#          S-Bahn Garage    Miete Nebenkosten  ... Terrasse Kehrwoche Moebliert  \
# 0           nah   nein  251-300      50-100  ...     nein      nein      nein
# 1           nah   nein  551-600     201-250  ...     nein      nein      nein
# 2    erreichbar   nein  551-600     151-200  ...     nein      nein      nein
# 3          nein   nein  251-300    unter 50  ...     nein      nein      nein
# 4    erreichbar     ja  751-800     251-300  ...     nein      nein      nein
# ..          ...    ...      ...         ...  ...      ...       ...       ...
# 260  erreichbar   nein  251-300      50-100  ...     nein      nein      nein
# 261        nein   nein  751-800     201-250  ...     nein      nein      nein
# 262         nah     ja  501-550     151-200  ...     nein      nein      nein
# 263  erreichbar   nein  601-650     201-250  ...     nein      nein      nein
# 264        nein   nein  501-550     151-200  ...     nein      nein      nein
#
#     Quadratmeter Kabelanschluss Deckenhöhe Abstellraum Waschraum  \
# 0          31-40           nein        250          ja      nein
# 1         91-100           nein        250        nein      nein
# 2          81-90             ja        250        nein      nein
# 3          20-30           nein        250          ja      nein
# 4       über 120           nein        250        nein        ja
# ..           ...            ...        ...         ...       ...
# 260        31-40           nein        280        nein      nein
# 261      111-120           nein        250          ja        ja
# 262        81-90           nein        260          ja      nein
# 263       91-100             ja        250          ja      nein
# 264        81-90           nein        250        nein      nein
#
#            Klasse Similarity
# 0     Studierende  18.000000
# 1            DINK  13.325412
# 2    Kleinfamilie  10.999864
# 3     Studierende  14.910517
# 4            DINK  10.740243
# ..            ...        ...
# 260   Studierende  13.977640
# 261  Kleinfamilie  12.801374
# 262          DINK  10.705448
# 263  Kleinfamilie  14.376659
# 264  Kleinfamilie  14.725160
#
# [265 rows x 28 columns]
# Most similiar case:
#     Zimmerzahl Stockwerk      Heizung Hausmeister Kindergarten      Schule  \
# 0  Zwei Zimmer   1.Stock  Gas-Zentral        nein          nah  erreichbar
#
#   S-Bahn Garage    Miete Nebenkosten  ... Terrasse Kehrwoche Moebliert  \
# 0    nah   nein  251-300      50-100  ...     nein      nein      nein
#
#   Quadratmeter Kabelanschluss Deckenhöhe Abstellraum Waschraum       Klasse  \
# 0        31-40           nein        250          ja      nein  Studierende
#
#   Similarity
# 0       18.0
#
# [1 rows x 28 columns]

# %% [markdown]
# ## Möglicherweise besser mit "Informierten" Ähnlichkeitsmaß
#
# ## --> Beachten von Ausprägungen pro Attribut
